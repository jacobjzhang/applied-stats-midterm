# %% [markdown]
# <b>Jacob J. Zhang</b><br>
# <i>CISC 5420 Midterm Project</i><br>
# Do Less Populated Regions Provide a Better Measure of Well-Being?
#
# The question that is being posed is whether or not regions of the United States with lower population counts tend to correlate with a higher level of well-being. In my travel experience, places with lower populations tend to leave me with a better impression of the area. Similarly, I'm constantly drawn to places in New York where there are less people. Admittedly, there could be multiple factors that prove wrong with this anecdotal reference. My preference could be due to my introverted nature and love for quiet, due to the fact that I was traveling versus residing in those areas, or even simply the time of year.
#
# I decided to find out if this was true for residnets through data analysis. To measure well-being, we will use a microcosmic version of the Human Development Index, a metric comprised of access of healthcare, educational attainment level, and income, which strives to measure the well-being of nations. Our data sets come from the last U.S. census, and to exclude cultural and ethnic factors, we will focus entirely on the United States. Our HDI will be derived from the data points we have.
#
# The first step is to take a look at our population data and determine what constitutes a large population versus a small one. We'll build a histogram to see the distribution:

# %%
# %matplotlib inline
import numpy
import pandas
import scipy
from scipy import stats

populations = pandas.read_csv('datasets/population_values.csv', sep=',', index_col=False, encoding='latin-1', skiprows=1, skipfooter=4, engine='python')
print(populations.columns)
pop_index = populations.set_index('Geographic region', drop=False)
latest_pop = pop_index[pop_index['Geographic region'] != 'United States']['Population Estimate (as of July 1) - 2015']
print(latest_pop.plot(kind='hist', bins=50, normed=False, legend=True))
# Out:
# Index(['Id', 'Id2', 'Geography', 'Target Geo Id', 'Target Geo Id2', 'Country',
#        'Geographic region', 'April 1, 2010 - Census',
#        'April 1, 2010 - Estimates Base',
#        'Population Estimate (as of July 1) - 2010',
#        'Population Estimate (as of July 1) - 2011',
#        'Population Estimate (as of July 1) - 2012',
#        'Population Estimate (as of July 1) - 2013',
#        'Population Estimate (as of July 1) - 2014',
#        'Population Estimate (as of July 1) - 2015'],
#       dtype='object')
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# The above histogram tells us that at around 500,000 people, the number of U.S. regions dramatically tapers off. At initial glance, this looks like a Pareto distribution, as the tail clearly extends on the right. There is quite a spread of values. To ensure we have enough high population areas, we can begin at the tail and settle on anything under 500,000 residents as being labeled a "small region", and those above being labeled as a "large region".
#
# We can now examine the first third of our well-being equation, namely education. In examining the columns and types of educational services, we get the following overview:

# %%
frame = pandas.read_csv('datasets/educational_est_values.csv', sep=',', encoding='latin-1', skiprows=1)
print("List of Columns\n")
print(frame.columns)
edu_by_geo = frame.set_index('Geographic area name', drop=False)
print("\nType of Educational Services and Totals\n")
print(edu_by_geo['Meaning of 2012 NAICS code'].value_counts())
# Out:
# List of Columns
#
# Index(['Geographic identifier code', 'Id2', 'Geographic area name',
#        '2012 NAICS code', 'Meaning of 2012 NAICS code',
#        'Type of operation or tax status code',
#        'Meaning of Type of operation or tax status code', 'Year',
#        'Number of establishments', 'Receipts/Revenue ($1,000)',
#        'Operating expenses ($1,000)', 'Annual payroll ($1,000)',
#        'First-quarter payroll ($1,000)',
#        'Number of paid employees for pay period including March 12',
#        'Percent of receipts/revenue from administrative records (%)',
#        'Percent of receipts/revenue estimated (%)'],
#       dtype='object')
#
# Type of Educational Services and Totals
#
# Educational support services                               1269
# Educational services                                        990
# Sports and recreation instruction                           922
# Fine arts schools                                           916
# Technical and trade schools                                 908
# Professional and management development training            824
# Other schools and instruction                               491
# Computer training                                           482
# Language schools                                            470
# All other schools and instruction                           466
# Exam preparation and tutoring                               442
# Business schools and computer and management training       423
# Dance schools (including children's and professionals')     419
# All other miscellaneous schools and instruction             393
# Art, drama, and music schools                               383
# Other technical and trade schools                           374
# Cosmetology and barber schools                              316
# Automobile driving schools                                  295
# Apprenticeship training                                     290
# Flight training                                             224
# Business and secretarial schools                            186
# Name: Meaning of 2012 NAICS code, dtype: int64

# %% [markdown]
# Knowing that, we can also generalize and look at all educational establishments per region, as the separation between the establishment types is not crucial for our analysis.
#
# To get a better intuition for this particular series, the maximum and minimum values will also be counted. Sorting all educational establishments reveal that the NY-NJ-CT-PA region has the most educational establishments, while Martin-Union City has the least. This is expected, as larger populations would correlate with more schools, training facilities, vocational centers, etc.
#
# It is also important to know how many regions we will be analyzing. To keep the sample size small, we will only count unique regions, which tally up to 166.
#
# At this point, plotting out the distribution of the number of educational establishments should us see where the distribution for most regions lay. Aside from a few outliers, all seem to be under 5,000 establishments.

# %%
print('Total Regions :', len(edu_by_geo['Geographic area name'].unique()))
all_edu_est = edu_by_geo[edu_by_geo['Meaning of Type of operation or tax status code'] == 'All establishments']
flattened_all_edu_est = all_edu_est.groupby('Geographic area name').sum().sort_values(by='Number of establishments', ascending=False)
print('Maximum :', flattened_all_edu_est['Number of establishments'].idxmax(), flattened_all_edu_est['Number of establishments'].max())
print('Minimum :', flattened_all_edu_est['Number of establishments'].idxmin(), flattened_all_edu_est['Number of establishments'].min())
print(flattened_all_edu_est['Number of establishments'].plot(kind='hist', bins=20, label="Number of Educational Establishments", legend=True))
# Out:
# Total Regions : 166
# Maximum : New York-Newark, NY-NJ-CT-PA CSA 38887
# Minimum : Martin-Union City, TN-KY CSA 21
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# The above histogram doesn't provide any new insights. At this step, the population can now be concatenated with the previous table dictating the number of establishments. We expect a high correlation between the number of establishments in a region and its population estimate, and we find this to be true when calculated.
#
# Because using raw establishment counts and population estimates will provide sufficient insight, it is important to then calculate the number of residents per educational establishments. This gives a sense of how many people each school or training facility can service-- a far better metric to use when determining well-being.
# We can do this by calculating residents per establishment, a variable which tells us how many students each center can cater to.

# %%
edu_and_pop = pandas.concat([flattened_all_edu_est['Number of establishments'], latest_pop], axis=1).sort_values(by='Population Estimate (as of July 1) - 2015')
print(edu_and_pop.corr())

edu_table = pandas.concat([flattened_all_edu_est['Number of establishments'], latest_pop], axis=1)
edu_table['Residents per Edu. Est.'] = edu_table['Population Estimate (as of July 1) - 2015'] / edu_table['Number of establishments']
full_edu_table = edu_table[['Residents per Edu. Est.', 'Population Estimate (as of July 1) - 2015']].sort_values(by='Residents per Edu. Est.')
pandas.set_option('max_colwidth',20)
full_edu_table
# Out:
#                       Number of establishments  \
# Number of establi...             1.000000
# Population Estima...             0.981838
#
#                       Population Estimate (as of July 1) - 2015
# Number of establi...             0.981838
# Population Estima...             1.000000
#                       Residents per Edu. Est.  \
# Edwards-Glenwood ...           387.685629
# Reno-Carson City-...             605706.0
# Lincoln-Beatrice,...             345478.0
# Orlando-Deltona-D...            3129308.0
# Jacksonville-St. ...            1573606.0
# Philadelphia-Read...            7183479.0
# Asheville-Brevard...             480051.0
# ...                                   ...
# Cleveland-Indiano...              60327.0
# Tyler-Jacksonvill...             274478.0
# Dothan-Enterprise...             248947.0
# Fresno-Madera, CA...            1129859.0
# Jonesboro-Paragou...             172590.0
# Mount Pleasant-Al...             112238.0
# Rome-Summerville,...             121426.0
# Midland-Odessa, T...             326154.0
# Modesto-Merced, C...             806843.0
# DeRidder-Fort Pol...              87265.0
# Joplin-Miami, MO-...             209192.0
# Charleston-Huntin...             693726.0
# Chattanooga-Cleve...             950005.0
# Williamsport-Lock...             155489.0
# Johnstown-Somerse...             211933.0
# Bloomsburg-Berwic...             263873.0
# Hickory-Lenoir, N...             407499.0
# McAllen-Edinburg,...             906099.0
# Pullman-Moscow, W...              86955.0
# Brownsville-Harli...             444059.0
# Longview-Marshall...             284527.0
# Visalia-Portervil...             610828.0
# Mansfield-Ashland...             217226.0
# Clovis-Portales, ...              69518.0
# Martin-Union City...              70837.0
# Dixon-Sterling, I...              91663.0
# Elmira-Corning, N...             184702.0
# Moses Lake-Othell...             112513.0
# Pueblo-Caon City...             210283.0
# Pueblo-CaÐon City...                  NaN
#
# [167 rows x 2 columns]

# %% [markdown]
# We can now plot this new variable and see if there are distinguishing characteristics between smaller and large populations. It seems that the majority of the establishments service around 1,000 people, tough some are servicing nearly 5,000. In terms of well-being, we can argue that the lower number of people that an establishment has to cater to, the better. This is due to more individual attention and better ease of organization.
#
# By plotting the CDF, we can see that at the 50th percentile, large regions (in blue) tend to cater to around 1,000 residents per institution, whereas smaller regions need to cater to nearly 1,400. This is the first instance where one aspect of our well-being equation favors areas with higher population.

# %%
large_regions = full_edu_table[full_edu_table['Population Estimate (as of July 1) - 2015'] > 500000]
small_regions = full_edu_table[full_edu_table['Population Estimate (as of July 1) - 2015'] < 500000]

ser1 = large_regions['Residents per Edu. Est.']
cum_dist = numpy.linspace(0.,1., len(ser1))
ser_cdf = pandas.Series(cum_dist, index=ser1)
edu_plot = ser_cdf.plot(drawstyle='line', label="Large Regions", legend=True)

ser2 = small_regions['Residents per Edu. Est.']
cum_dist = numpy.linspace(0.,1., len(ser2))
ser_cdf2 = pandas.Series(cum_dist, index=ser2)
edu_plot.plot(ser_cdf2, label="Small Regions")

# %% [markdown]
# Though access to educational institutions is great, even more important is how many educational staffers there are. We can calculate this by calculating the number of educational employees per resident, a variable which tells us how many educational employees such as teachers and coaches are available per resident. In this case, the higher the better as this means more resources.

# %%
all_edu_est = edu_by_geo[edu_by_geo['Meaning of Type of operation or tax status code'] == 'All establishments']
edu_receipt_employee = all_edu_est.groupby('Geographic area name').sum().sort_values(by='Receipts/Revenue ($1,000)', ascending=False)
ere = edu_receipt_employee[['Receipts/Revenue ($1,000)', 'Number of paid employees for pay period including March 12']]
ere_pop = pandas.concat([ere, latest_pop], axis=1)
ere_pop['Edu. Employees per Resident'] = ere_pop['Number of paid employees for pay period including March 12'] / ere_pop['Population Estimate (as of July 1) - 2015']
ere_pop['Edu Emp Res Pct'] = scipy.stats.rankdata(ere_pop['Edu. Employees per Resident'], "average")/len(ere_pop['Edu. Employees per Resident'])

educators = ere_pop[['Edu Emp Res Pct', 'Population Estimate (as of July 1) - 2015']].sort_values(by='Population Estimate (as of July 1) - 2015')

large_educators = ere_pop[ere_pop['Population Estimate (as of July 1) - 2015'] > 500000]
small_educators = ere_pop[ere_pop['Population Estimate (as of July 1) - 2015'] < 500000]

lep = large_educators.plot(kind='hist', y='Edu Emp Res Pct', x='Population Estimate (as of July 1) - 2015', figsize=(20, 10), bins=100, label="Educational Employees in High Pop Regions")
small_educators.plot(ax=lep, kind='hist', y='Edu Emp Res Pct', x='Population Estimate (as of July 1) - 2015', figsize=(20, 10), bins=100, label="Educational Employees in Low Pop Regions")

# %% [markdown]
# A quick analysis shows that as the population grows, there does seem to be a trend towards more teachers, coaches, trainers, etc. There is a greater likelihood that of a higher percentile (more educational employees) in regions with greater populations.
#
# We can now incorporate the number of healthcare institutions. It would be interesting to find the number of healthcare establishments compared to the number of educational establishments. As expected there is a tight correlation, largely because both numbers derive from population.

# %%
health_est = pandas.read_csv('datasets/health_est_values.csv', sep=',', encoding='latin-1', skiprows=1)
health_est = health_est.set_index('Geographic area name', drop=False)
health_est_all = health_est[health_est['Meaning of Type of operation or tax status code'] == 'All establishments']
flattened_all_health_est = health_est_all.groupby('Geographic area name').sum().sort_values(by='Number of establishments', ascending=False)
flattened_all_edu_est = all_edu_est.groupby('Geographic area name').sum().sort_values(by='Number of establishments', ascending=False)
health_edu_est = pandas.concat([flattened_all_health_est['Number of establishments'], flattened_all_edu_est['Number of establishments']], axis=1)
health_edu_est.columns = ['Health Establishments', 'Educational Establishments']

print(health_edu_est.corr())
# Out:
#                       Health Establishments  Educational Establishments
# Health Establishm...             1.000000               0.987437
# Educational Estab...             0.987437               1.000000

# %% [markdown]
# Let's investigate what the differences are in the number of educational establishments when accounting for population. We can similarly create a variable called "Residents per Health Establishment", which tracks how many residents the establishments in small and large regions can cater to.

# %%
health_pop_table = pandas.concat([flattened_all_health_est['Number of establishments'], latest_pop], axis=1)
health_pop_table['Residents per Health Est.'] = health_pop_table['Population Estimate (as of July 1) - 2015'] / health_pop_table['Number of establishments']
health_pop_table = health_pop_table.sort_values(by='Residents per Health Est.')

hlarge_regions = health_pop_table[health_pop_table['Population Estimate (as of July 1) - 2015'] > 1000000]
hsmall_regions = health_pop_table[health_pop_table['Population Estimate (as of July 1) - 2015'] < 1000000]

hser1 = hlarge_regions['Residents per Health Est.']
hcum_dist = numpy.linspace(0.,1., len(hser1))
hser_cdf = pandas.Series(hcum_dist, index=hser1)
hlarge_plot = hser_cdf.plot(drawstyle='line', label="Large Regions", legend=True)

hser2 = hsmall_regions['Residents per Health Est.']
hcum_dist = numpy.linspace(0.,1., len(hser2))
hser_cdf2 = pandas.Series(hcum_dist, index=hser2)
hlarge_plot.plot(hser_cdf2, label="Small Regions")

# %% [markdown]
# We can see that at the lower percentiles, the smaller regions line is closer to the y-axis. This means in terms of residents per healthcare establishment, smaller regions win because there is more availability for healthcare. However, once the "residents per healthcare establishment" variable hits a certain point, large regions are able to provide at a slightly higher rate than smaller ones.

# %% [markdown]
# What's interesting to note is that the "residents per healthcare institution" figures have a slightly more even distribution than residents per educational institution. This could be explained by many reasons-- one of which is that society places a higher priority on healthcare than on education, and the distinction between large regions and smaller regions's healthcare services isn't as great. Another possibility could be that healthcare is more meritocratic than education.
#
# We can now examine another crucial variable, and that is one of health cost per resident. We can obtain this by dividing the total revenues of the healthcare establishments in a region and dividing by population.

# %%
flattened_all_health_est = health_est_all.groupby('Geographic area name').sum().sort_values(by='Number of establishments', ascending=False)
health_receipt_employee = health_est_all.groupby('Geographic area name').sum().sort_values(by='Number of paid employees for pay period including March 12', ascending=False)
hre = health_receipt_employee[['Receipts/Revenue ($1,000)', 'Number of paid employees for pay period including March 12']]
hrep = pandas.concat([hre, latest_pop], axis=1)
hrep['Health Cost Per Resident'] = hrep['Receipts/Revenue ($1,000)'] / hrep['Population Estimate (as of July 1) - 2015']
hrep_pop = hrep[['Health Cost Per Resident', 'Population Estimate (as of July 1) - 2015']].sort_values(by='Population Estimate (as of July 1) - 2015', ascending=True)
hrep_pop['Health Cost Per Resident Pct'] = scipy.stats.rankdata(hrep_pop['Health Cost Per Resident'], "average")/len(hrep_pop['Health Cost Per Resident'])

hrep_mean = hrep_pop['Health Cost Per Resident Pct'].mean()
hrep_std = hrep_pop['Health Cost Per Resident Pct'].std()

print("Mean: ", hrep_mean, "Standard Deviation: ", hrep_std)

hrep_pop['Normal Dist'] = scipy.stats.norm.cdf(hrep_pop['Health Cost Per Resident Pct'], loc=hrep_mean, scale=hrep_std)

hrep_pop_chart = hrep_pop[['Health Cost Per Resident Pct', 'Normal Dist', 'Population Estimate (as of July 1) - 2015']].set_index('Population Estimate (as of July 1) - 2015', drop=False)

pop_estimate = hrep_pop_chart['Population Estimate (as of July 1) - 2015']
hcdist = hrep_pop_chart['Health Cost Per Resident Pct']
cdf1 = pandas.Series(hcdist, index=pop_estimate)
plot1 = cdf1.plot(drawstyle='line', label="Health Cost Per Resident Percentile", xlim=((0,3000000)), figsize=(20, 10), legend=True)

pop_estimate = hrep_pop_chart['Population Estimate (as of July 1) - 2015']
nmdist = hrep_pop_chart['Normal Dist']
cdf2 = pandas.Series(nmdist, index=pop_estimate)
plot1.plot(cdf2, label="Percentile Normal Distribution")
# Out:
# Mean:  0.5029940119760479 Standard Deviation:  0.2895381414068643

# %% [markdown]
# After plotting the normal distribution (in green) over the values for Health Cost Per Resident Percentile by population, we can see that in multiple cases where the lines don't align, the Health Cost is lower than we would expect. This is especially noticeable towards the regions with larger populations of greater than 500,000 residents. The conclusion we can draw is that in high population regions, Health Cost Per Resident seems to be slightly lower than we expect from a normal distribution.
#
# We'll now want to incorporate incomes and wealth into this equation. A column called "Payroll per employee" was calculated by dividing the "Annual payroll" of a region with its "number of paid employees". While not wholly accurate, we care more about the relativitiy of the incomes than on precision. We can then integrate this in with the rest of our data. Unsurprisingly, the regions with the largest populations tend to have higher payroll amounts as well.

# %%
business = pandas.read_csv('datasets/business_est_values.csv', sep=',', encoding='latin-1', skiprows=13, skipfooter=24, engine='python') 
# Pueblo-Caon City...                  NaN                    NaN
#
#                      Payroll Per Employee  \
# Brownsville-Harli...                   26
# McAllen-Edinburg,...                   26
# Clovis-Portales, ...                   27
# Hot Springs-Malve...                   28
# Martin-Union City...                   28
# Manhattan-Junctio...                   28
# Myrtle Beach-Conw...                   29
# El Paso-Las Cruce...                   29
# Lubbock-Levelland...                    3
# Fayetteville-Lumb...                   30
# New Bern-Morehead...                   31
# DeRidder-Fort Pol...                   31
# Cleveland-Indiano...                   31
# Jonesboro-Paragou...                   32
# Mount Pleasant-Al...                   32
# Johnstown-Somerse...                   32
# Rapid City-Spearf...                   32
# Pullman-Moscow, W...                   32
# Gainesville-Lake ...                   33
# Knoxville-Morrist...                   33
# Ithaca-Cortland, ...                   33
# Columbus-Auburn-O...                   33
# Macon-Warner Robi...                   33
# Dothan-Enterprise...                   33
# Idaho Falls-Rexbu...                   33
# Bloomington-Bedfo...                   33
# Visalia-Portervil...                   33
# Cape Girardeau-Si...                   33
# Richmond-Connersv...                   33
# Bowling Green-Gla...                   33
# ...                                   ...
# Des Moines-Ames-W...                   44
# Milwaukee-Racine-...                   45
# Cincinnati-Wilmin...                   45
# Jacksonville-St. ...                   45
# Portland-Vancouve...                   45
# Birmingham-Hoover...                   45
# Bloomington-Ponti...                   45
# St. Louis-St. Cha...                   46
# Midland-Odessa, T...                   46
# Boise City-Mounta...                   46
# Sacramento-Rosevi...                   46
# Detroit-Warren-An...                   47
# Raleigh-Durham-Ch...                   47
# Charlotte-Concord...                   47
# Los Angeles-Long ...                   47
# Dallas-Fort Worth...                   48
# Atlanta--Athens-C...                   48
# Seattle-Tacoma, W...                   50
# Philadelphia-Read...                   50
# Denver-Aurora, CO...                   50
# Chicago-Napervill...                   51
# Minneapolis-St. P...                   51
# Peoria-Canton, IL...                   52
# Hartford-West Har...                   52
# Boston-Worcester-...                   54
# Washington-Baltim...                   54
# Houston-The Woodl...                   55
# New York-Newark, ...                   61
# San Jose-San Fran...                   74
# Pueblo-Caon City...                  NaN
#
#                       Population Estimate (as of July 1) - 2015
# Brownsville-Harli...             444059.0
# McAllen-Edinburg,...             906099.0
# Clovis-Portales, ...              69518.0
# Hot Springs-Malve...             130603.0
# Martin-Union City...              70837.0
# Manhattan-Junctio...             135575.0
# Myrtle Beach-Conw...             493262.0
# El Paso-Las Cruce...            1053267.0
# Lubbock-Levelland...             334587.0
# Fayetteville-Lumb...             546215.0
# New Bern-Morehead...             195124.0
# DeRidder-Fort Pol...              87265.0
# Cleveland-Indiano...              60327.0
# Jonesboro-Paragou...             172590.0
# Mount Pleasant-Al...             112238.0
# Johnstown-Somerse...             211933.0
# Rapid City-Spearf...             168961.0
# Pullman-Moscow, W...              86955.0
# Gainesville-Lake ...             345511.0
# Knoxville-Morrist...            1109174.0
# Ithaca-Cortland, ...             153420.0
# Columbus-Auburn-O...             504865.0
# Macon-Warner Robi...             418245.0
# Dothan-Enterprise...             248947.0
# Idaho Falls-Rexbu...             235829.0
# Bloomington-Bedfo...             211072.0
# Visalia-Portervil...             610828.0
# Cape Girardeau-Si...             136542.0
# Richmond-Connersv...              90435.0
# Bowling Green-Gla...             221915.0
# ...                                   ...
# Des Moines-Ames-W...             782390.0
# Milwaukee-Racine-...            2046692.0
# Cincinnati-Wilmin...            2216735.0
# Jacksonville-St. ...            1573606.0
# Portland-Vancouve...            3110906.0
# Birmingham-Hoover...            1319238.0
# Bloomington-Ponti...             226084.0
# St. Louis-St. Cha...            2916447.0
# Midland-Odessa, T...             326154.0
# Boise City-Mounta...             756061.0
# Sacramento-Rosevi...            2544026.0
# Detroit-Warren-An...            5319913.0
# Raleigh-Durham-Ch...            2117103.0
# Charlotte-Concord...            2583956.0
# Los Angeles-Long ...           18679763.0
# Dallas-Fort Worth...            7504362.0
# Atlanta--Athens-C...            6365108.0
# Seattle-Tacoma, W...            4602591.0
# Philadelphia-Read...            7183479.0
# Denver-Aurora, CO...            3418876.0
# Chicago-Napervill...            9923358.0
# Minneapolis-St. P...            3866768.0
# Peoria-Canton, IL...             413717.0
# Hartford-West Har...            1483187.0
# Boston-Worcester-...            8152573.0
# Washington-Baltim...            9625360.0
# Houston-The Woodl...            6855069.0
# New York-Newark, ...           23723696.0
# San Jose-San Fran...            8713914.0
# Pueblo-Caon City...             210283.0
#
# [167 rows x 4 columns]

# %%
full_table = pandas.concat([health_edu_est, business_grouped['Payroll Per Employee']], axis=1).sort_values(by='Payroll Per Employee').dropna()
edu_table = pandas.concat([flattened_all_edu_est['Number of establishments'], latest_pop], axis=1)
full_table['Residents per Edu. Est.'] = edu_table['Population Estimate (as of July 1) - 2015'] / edu_table['Number of establishments']
health_table = pandas.concat([flattened_all_health_est['Number of establishments'], latest_pop], axis=1)
full_table['Residents per Health Est.'] = health_table['Population Estimate (as of July 1) - 2015'] / health_table['Number of establishments']
full_table.astype(float).corr()
# Out:
#                       Health Establishments  Educational Establishments  \
# Health Establishm...             1.000000               0.987437
# Educational Estab...             0.987437               1.000000
# Payroll Per Employee             0.591284               0.605825
# Residents per Edu...            -0.296601              -0.306590
# Residents per Hea...            -0.157164              -0.144445
#
#                       Payroll Per Employee  Residents per Edu. Est.  \
# Health Establishm...             0.591284             -0.296601
# Educational Estab...             0.605825             -0.306590
# Payroll Per Employee             1.000000             -0.358772
# Residents per Edu...            -0.358772              1.000000
# Residents per Hea...            -0.074673              0.414564
#
#                       Residents per Health Est.
# Health Establishm...            -0.157164
# Educational Estab...            -0.144445
# Payroll Per Employee            -0.074673
# Residents per Edu...             0.414564
# Residents per Hea...             1.000000

# %% [markdown]
# Surprisingly, payroll correlates the least with population. This could be due to fiercier and greater competition, a wider range of employment, and many other reasons. With that said, there is still a positive correlation with the other variables, leading us to our next analysis.
#
# The most important step now will be deriving our microcosmic HDI. To do this, we will take the two relative figures (residents per educational establishment and residents per healthcare establishment) and compare them to the max and mins of their series to achieve a relative score. We will then do the same with payroll to see which regions provide the highest level of well-being.

# %%
from scipy import stats
from scipy.stats.mstats import gmean

full_table['Residents Per Edu Percentile'] = 1 - stats.rankdata(full_table['Residents per Edu. Est.'], "average")/len(full_table['Residents per Edu. Est.'])
full_table['Residents Per Health Percentile'] = 1 - stats.rankdata(full_table['Residents per Health Est.'], "average")/len(full_table['Residents per Health Est.'])
full_table['Payroll Percentile'] = (stats.rankdata(full_table['Payroll Per Employee'], "average")/len(full_table['Payroll Per Employee']))
res = full_table['Residents Per Edu Percentile'] * full_table['Residents Per Health Percentile'] * full_table['Payroll Percentile'] 
full_table['HDI Percentile'] = res**(1. / 3.)
clean_full_table = full_table[['Residents Per Edu Percentile', 'Residents Per Health Percentile', 'Payroll Percentile', 'HDI Percentile']]
clean_full_table.sort_values(by='HDI Percentile')
# Out:
#                       Residents Per Edu Percentile  \
# Geographic area name
# Pueblo-CaÐon City...             0.000000
# Moses Lake-Othell...             0.006024
# DeRidder-Fort Pol...             0.114458
# Clovis-Portales, ...             0.030120
# Visalia-Portervil...             0.042169
# Brownsville-Harli...             0.054217
# McAllen-Edinburg,...             0.066265
# El Paso-Las Cruce...             0.198795
# Dixon-Sterling, I...             0.018072
# Martin-Union City...             0.024096
# Pullman-Moscow, W...             0.060241
# Hickory-Lenoir, N...             0.072289
# Columbus-Auburn-O...             0.174699
# Modesto-Merced, C...             0.120482
# Manhattan-Junctio...             0.602410
# Mobile-Daphne-Fai...             0.385542
# Lafayette-West La...             0.265060
# Fayetteville-Lumb...             0.210843
# Elmira-Corning, N...             0.012048
# Dothan-Enterprise...             0.156627
# Myrtle Beach-Conw...             0.397590
# Mansfield-Ashland...             0.036145
# Hot Springs-Malve...             0.271084
# Cleveland-Indiano...             0.168675
# Chattanooga-Cleve...             0.096386
# Knoxville-Morrist...             0.222892
# Harrisonburg-Stau...             0.481928
# Johnstown-Somerse...             0.084337
# Longview-Marshall...             0.048193
# Savannah-Hinesvil...             0.234940
# ...                                   ...
# Spokane-Spokane V...             0.789157
# Saginaw-Midland-B...             0.463855
# Reno-Carson City-...             0.849398
# Albuquerque-Santa...             0.921687
# Omaha-Council Blu...             0.698795
# Victoria-Port Lav...             0.554217
# Kansas City-Overl...             0.777108
# Jacksonville-St. ...             0.831325
# Oklahoma City-Sha...             0.596386
# Steamboat Springs...             0.987952
# Boise City-Mounta...             0.638554
# Albany-Schenectad...             0.783133
# Pittsburgh-New Ca...             0.608434
# Washington-Baltim...             0.945783
# Detroit-Warren-An...             0.662651
# Milwaukee-Racine-...             0.765060
# Los Angeles-Long ...             0.807229
# St. Louis-St. Cha...             0.644578
# Chicago-Napervill...             0.879518
# Minneapolis-St. P...             0.915663
# Denver-Aurora, CO...             0.981928
# Portland-Lewiston...             0.909639
# Philadelphia-Read...             0.825301
# Portland-Vancouve...             0.891566
# Boston-Worcester-...             0.957831
# Hartford-West Har...             0.885542
# Miami-Fort Lauder...             0.903614
# San Jose-San Fran...             0.969880
# Seattle-Tacoma, W...             0.975904
# New York-Newark, ...             0.963855
#
#                       Residents Per Health Percentile  Payroll Percentile  \
# Geographic area name
# Pueblo-CaÐon City...             0.000000                        0.231928
# Moses Lake-Othell...             0.006024                        0.518072
# DeRidder-Fort Pol...             0.012048                        0.072289
# Clovis-Portales, ...             0.192771                        0.018072
# Visalia-Portervil...             0.018072                        0.153614
# Brownsville-Harli...             0.331325                        0.009036
# McAllen-Edinburg,...             0.409639                        0.009036
# Mobile-Daphne-Fai...        0.139133
# Lafayette-West La...        0.150869
# Fayetteville-Lumb...        0.152113
# Elmira-Corning, N...        0.154213
# Dothan-Enterprise...        0.159508
# Myrtle Beach-Conw...        0.160209
# Mansfield-Ashland...        0.167301
# Hot Springs-Malve...        0.182217
# Cleveland-Indiano...        0.184139
# Chattanooga-Cleve...        0.185079
# Knoxville-Morrist...        0.189515
# Harrisonburg-Stau...        0.194927
# Johnstown-Somerse...        0.199440
# Longview-Marshall...        0.201011
# Savannah-Hinesvil...        0.206246
# ...                              ...
# Spokane-Spokane V...        0.674832
# Saginaw-Midland-B...        0.681516
# Reno-Carson City-...        0.681580
# Albuquerque-Santa...        0.685485
# Omaha-Council Blu...        0.693651
# Victoria-Port Lav...        0.698757
# Kansas City-Overl...        0.701280
# Jacksonville-St. ...        0.701884
# Oklahoma City-Sha...        0.715048
# Steamboat Springs...        0.717730
# Boise City-Mounta...        0.722294
# Albany-Schenectad...        0.724388
# Pittsburgh-New Ca...        0.771247
# Washington-Baltim...        0.776669
# Detroit-Warren-An...        0.777767
# Milwaukee-Racine-...        0.795210
# Los Angeles-Long ...        0.797392
# St. Louis-St. Cha...        0.801056
# Chicago-Napervill...        0.817512
# Minneapolis-St. P...        0.823414
# Denver-Aurora, CO...        0.824967
# Portland-Lewiston...        0.833605
# Philadelphia-Read...        0.833644
# Portland-Vancouve...        0.855996
# Boston-Worcester-...        0.871039
# Hartford-West Har...        0.881942
# Miami-Fort Lauder...        0.885468
# San Jose-San Fran...        0.888376
# Seattle-Tacoma, W...        0.900112
# New York-Newark, ...        0.935814
#
# [166 rows x 4 columns]

# %% [markdown]
# When accounting for access to healthcare, education availability, and average income, the larger cities do seem to come out ahead. Some of the nation's most populated regions, included the tri-state area and the bay area, rank the highest when everything is accounted for. However, to confirm this, let's analyze the distribution of HDI and try to see if there is a substantial difference when accounting for population.

# %%
HDIpct = clean_full_table['HDI Percentile']
hdi_pop = pandas.concat([HDIpct, latest_pop], axis=1)

hp_small_regions = hdi_pop[hdi_pop['Population Estimate (as of July 1) - 2015'] < 500000].set_index('Population Estimate (as of July 1) - 2015', drop=False)
hp_large_regions = hdi_pop[hdi_pop['Population Estimate (as of July 1) - 2015'] > 500000].set_index('Population Estimate (as of July 1) - 2015', drop=False)

small_plot = hp_small_regions.plot(kind='scatter', y='HDI Percentile', x='Population Estimate (as of July 1) - 2015', legend=True, label="Small Regions", figsize=(20, 10))
hp_large_regions.plot(ax=small_plot, kind='scatter', y='HDI Percentile', x='Population Estimate (as of July 1) - 2015', legend=True, label="Large Regions", color='r')

# %% [markdown]
# If population is above 500,000, it appears we are far more likely to have a high HDI. The vast majority of the points that are in red, and thus with larger populations, hover above the 50% percentile.

# %% [markdown]
# These plots show what we've seen all along-- when looking at the higher HDI percentiles, larger regions are much more likely to end up there. This is due to the variables we have analyzed-- higher wages, more availability to healthcare and medical professionals, and more access to education.
#
# With that said, the original question can answered with a resounding "no". Smaller regions have lost on every front with the exception of healthcare costs, which fluctuate. A hypothesis for this is that healthcare is viewed as a meritocratic need, and thus has a more normal distribution when accounted for.
