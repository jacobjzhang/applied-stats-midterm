# %% [markdown]
# Midterm Project <br>
# Do Less Populated Regions Provide a Better Measure of Well-Being?
#
# The first step is to wrangle our data so that we are able to properly utilize the thinkstats2 and pandas libraries. We'll start with the data on educational establishments and build up better column names.

# %%
# %matplotlib inline

import numpy
import pandas
# import thinkstats2

frame = pandas.read_csv('datasets/educational_est_values.csv', sep=',', encoding='latin-1', skiprows=1)
edu_by_geo = frame.set_index('Geographic area name', drop=False)
print("List of columns\n")
print(edu_by_geo.columns)
print("\nType of Educational Services and Totals\n")
print(edu_by_geo['Meaning of 2012 NAICS code'].value_counts())
# Out:
# List of columns
#
# Index(['Geographic identifier code', 'Id2', 'Geographic area name',
#        '2012 NAICS code', 'Meaning of 2012 NAICS code',
#        'Type of operation or tax status code',
#        'Meaning of Type of operation or tax status code', 'Year',
#        'Number of establishments', 'Receipts/Revenue ($1,000)',
#        'Operating expenses ($1,000)', 'Annual payroll ($1,000)',
#        'First-quarter payroll ($1,000)',
#        'Number of paid employees for pay period including March 12',
#        'Percent of receipts/revenue from administrative records (%)',
#        'Percent of receipts/revenue estimated (%)'],
#       dtype='object')
#
# Type of Educational Services and Totals
#
# Educational support services                               1269
# Educational services                                        990
# Sports and recreation instruction                           922
# Fine arts schools                                           916
# Technical and trade schools                                 908
# Professional and management development training            824
# Other schools and instruction                               491
# Computer training                                           482
# Language schools                                            470
# All other schools and instruction                           466
# Exam preparation and tutoring                               442
# Business schools and computer and management training       423
# Dance schools (including children's and professionals')     419
# All other miscellaneous schools and instruction             393
# Art, drama, and music schools                               383
# Other technical and trade schools                           374
# Cosmetology and barber schools                              316
# Automobile driving schools                                  295
# Apprenticeship training                                     290
# Flight training                                             224
# Business and secretarial schools                            186
# Name: Meaning of 2012 NAICS code, dtype: int64

# %%
# print(edu_by_geo['Geographic area name'].value_counts())
# The above is an issue, we need to find the number of establishments in each region.

print(len(edu_by_geo['Geographic area name'].unique()))
# Out:
# 166

# %%
all_edu_est = edu_by_geo[edu_by_geo['Meaning of Type of operation or tax status code'] == 'All establishments']
flattened_all_edu_est = all_edu_est.groupby('Geographic area name').sum().sort('Number of establishments', ascending=False)
print(flattened_all_edu_est['Number of establishments'])
# Out:
# Geographic area name
# New York-Newark, NY-NJ-CT-PA CSA                        38887
# Los Angeles-Long Beach, CA CSA                          21990
# Washington-Baltimore-Arlington, DC-MD-VA-WV-PA CSA      14766
# San Jose-San Francisco-Oakland, CA CSA                  14328
# Chicago-Naperville, IL-IN-WI CSA                        13399
# Boston-Worcester-Providence, MA-RI-NH-CT CSA            13233
# Miami-Fort Lauderdale-Port St. Lucie, FL CSA             9494
# Philadelphia-Reading-Camden, PA-NJ-DE-MD CSA             8670
# Atlanta--Athens-Clarke County--Sandy Springs, GA CSA     8519
# Seattle-Tacoma, WA CSA                                   8065
# Dallas-Fort Worth, TX-OK CSA                             7687
# Denver-Aurora, CO CSA                                    6674
# Houston-The Woodlands, TX CSA                            6118
# Minneapolis-St. Paul, MN-WI CSA                          5627
# Detroit-Warren-Ann Arbor, MI CSA                         5377
# Portland-Vancouver-Salem, OR-WA CSA                      4284
# Orlando-Deltona-Daytona Beach, FL CSA                    3812
# Cleveland-Akron-Canton, OH CSA                           3600
# Salt Lake City-Provo-Orem, UT CSA                        3457
# Raleigh-Durham-Chapel Hill, NC CSA                       3109
# St. Louis-St. Charles-Farmington, MO-IL CSA              2845
# Sacramento-Roseville, CA CSA                             2757
# Kansas City-Overland Park-Kansas City, MO-KS CSA         2740
# Charlotte-Concord, NC-SC CSA                             2725
# Indianapolis-Carmel-Muncie, IN CSA                       2517
# Pittsburgh-New Castle-Weirton, PA-OH-WV CSA              2480
# Milwaukee-Racine-Waukesha, WI CSA                        2268
# Columbus-Marion-Zanesville, OH CSA                       2219
# Virginia Beach-Norfolk, VA-NC CSA                        2048
# Cincinnati-Wilmington-Maysville, OH-KY-IN CSA            2033
#                                                         ...
# Sioux City-Vermillion, IA-SD-NE CSA                       128
# Manhattan-Junction City, KS CSA                           126
# Bloomsburg-Berwick-Sunbury, PA CSA                        122
# Pueblo-Cañon City, CO CSA                                 113
# Longview-Marshall, TX CSA                                 109
# Joplin-Miami, MO-OK CSA                                   109
# Victoria-Port Lavaca, TX CSA                              109
# Paducah-Mayfield, KY-IL CSA                               105
# Findlay-Tiffin, OH CSA                                    103
# Parkersburg-Marietta-Vienna, WV-OH CSA                    101
# Johnstown-Somerset, PA CSA                                100
# Jonesboro-Paragould, AR CSA                                97
# Cape Girardeau-Sikeston, MO-IL CSA                         90
# Steamboat Springs-Craig, CO CSA                            89
# Hot Springs-Malvern, AR CSA                                87
# Richmond-Connersville, IN CSA                              83
# Williamsport-Lock Haven, PA CSA                            74
# Quincy-Hannibal, IL-MO CSA                                 74
# Kokomo-Peru, IN CSA                                        73
# Mansfield-Ashland-Bucyrus, OH CSA                          72
# Rome-Summerville, GA CSA                                   67
# Mount Pleasant-Alma, MI CSA                                62
# Elmira-Corning, NY CSA                                     53
# DeRidder-Fort Polk South, LA CSA                           47
# Pullman-Moscow, WA-ID CSA                                  37
# Cleveland-Indianola, MS CSA                                36
# Dixon-Sterling, IL CSA                                     27
# Clovis-Portales, NM CSA                                    22
# Martin-Union City, TN-KY CSA                               21
# Moses Lake-Othello, WA CSA                                 21
# Name: Number of establishments, dtype: int64
# /Users/user/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
print(flattened_all_edu_est['Number of establishments'].max())
print(flattened_all_edu_est['Number of establishments'].min())
# Out:
# 38887
# 21

# %% [markdown]
# At this step, we will want to add population numbers to the data in order to see how these values compare relatively.

# %%
populations = pandas.read_csv('datasets/population_values.csv', sep=',', index_col=False, encoding='latin-1', skiprows=1, skipfooter=4)
print(populations.columns)
pop_index = populations.set_index('Geographic region', drop=False)
latest_pop = pop_index[pop_index['Geographic region'] != 'United States']['Population Estimate (as of July 1) - 2015']
print(latest_pop)
# Out:
# Index(['Id', 'Id2', 'Geography', 'Target Geo Id', 'Target Geo Id2', 'Country',
#        'Geographic region', 'April 1, 2010 - Census',
#        'April 1, 2010 - Estimates Base',
#        'Population Estimate (as of July 1) - 2010',
#        'Population Estimate (as of July 1) - 2011',
#        'Population Estimate (as of July 1) - 2012',
#        'Population Estimate (as of July 1) - 2013',
#        'Population Estimate (as of July 1) - 2014',
# Pullman-Moscow, W...              86955.0
# Brownsville-Harli...             444059.0
# Longview-Marshall...             284527.0
# Visalia-Portervil...             610828.0
# Mansfield-Ashland...             217226.0
# Clovis-Portales, ...              69518.0
# Martin-Union City...              70837.0
# Dixon-Sterling, I...              91663.0
# Elmira-Corning, N...             184702.0
# Moses Lake-Othell...             112513.0
# Pueblo-Caon City...             210283.0
# Pueblo-Cañon City...                  NaN
#
# [167 rows x 2 columns]

# %% [markdown]
# Below is a histogram of population count versus numbers of educational establishment. This will give us a more intuitive sense of whether or not larger populations are guaranteed to spawn much more educational establishments.

# %%
# import thinkstats2
# hist = thinkstats2.Hist(full_edu_table)

print(full_edu_table['Residents per Edu. Est.'].plot(by='Residents per Edu. Est.', kind='hist', bins=20))
# The vast majority of regions seem to serve around 1,000 residents per educational establishment.
# The lower the better.
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# Display the histogram.

# %%
import matplotlib.pyplot as plt
import scipy
import scipy.stats
size = 4000
x = scipy.arange(size)
y = full_edu_table['Residents per Edu. Est.'].astype(float).dropna().as_matrix()
h = plt.hist(y, bins=40, color='w')

dist_names = ['gamma', 'beta', 'norm', 'alpha', 'beta', 'betaprime']

for dist_name in dist_names:
    dist = getattr(scipy.stats, dist_name)
    param = dist.fit(y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    # pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=dist_name)
    plt.xlim(0,4000)
plt.legend(loc='upper right')
plt.show()
# Out:
# /Users/user/anaconda/lib/python3.5/site-packages/scipy/optimize/minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# It would be interesting to find the number of healthcare establishments compared to the number of educational establishments.

# %%
health_est = pandas.read_csv('datasets/health_est_values.csv', sep=',', encoding='latin-1', skiprows=1)
health_est = health_est.set_index('Geographic area name', drop=False)
health_est_all = health_est[health_est['Meaning of Type of operation or tax status code'] == 'All establishments']
flattened_all_health_est = health_est_all.groupby('Geographic area name').sum().sort('Number of establishments', ascending=False)

health_edu_est = pandas.concat([flattened_all_health_est['Number of establishments'], flattened_all_edu_est['Number of establishments']], axis=1)

health_edu_est.columns = ['Health Establishments', 'Educational Establishments']

print(health_edu_est)

print(health_edu_est.corr())
# Out:
#                       Health Establishments  Educational Establishments
# Albany-Schenectad...                16692                   1329
# Albuquerque-Santa...                15135                   1701
# Amarillo-Borger, ...                 3763                    184
# Appleton-Oshkosh-...                 4951                    342
# Asheville-Brevard...                 6959                    575
# Atlanta--Athens-C...                73267                   8519
# Bend-Redmond-Prin...                 3258                    303
# Birmingham-Hoover...                14490                   1029
# Bloomington-Bedfo...                 2245                    252
# Bloomington-Ponti...                 2390                    213
# Bloomsburg-Berwic...                 3534                    122
# Boise City-Mounta...                10292                    732
# Boston-Worcester-...               112850                  13233
# Bowling Green-Gla...                 2853                    163
# Brownsville-Harli...                 5245                    184
# Buffalo-Cheektowa...                16949                   1249
# Cape Coral-Fort M...                12556                    873
# Cape Girardeau-Si...                 2440                     90
# Cedar Rapids-Iowa...                 5610                    474
# Charleston-Huntin...                10887                    350
# Charlotte-Concord...                28063                   2725
# Chattanooga-Cleve...                10307                    466
# Chicago-Napervill...               134534                  13399
# Cincinnati-Wilmin...                25105                   2033
# Cleveland-Akron-C...                45223                   3600
# Cleveland-Indiano...                  775                     36
# Clovis-Portales, ...                  756                     22
# Columbia-Moberly-...                 3752                    245
# Columbia-Orangebu...                 9679                    936
# Columbus-Auburn-O...                 4960                    306
# ...                                   ...                    ...
# Rome-Summerville,...                 1558                     67
# Sacramento-Rosevi...                29671                   2757
# Saginaw-Midland-B...                 5793                    307
# Salt Lake City-Pr...                29603                   3457
# San Jose-San Fran...               121463                  14328
# Savannah-Hinesvil...                 5526                    347
# Seattle-Tacoma, W...                66988                   8065
# Sioux City-Vermil...                 2603                    128
# South Bend-Elkhar...                 7750                    528
# Spokane-Spokane V...                10662                    803
# Springfield-Brans...                 6382                    412
# Springfield-Green...                 9036                   1073
# Springfield-Jacks...                 3548                    262
# St. Louis-St. Cha...                45854                   2845
# State College-DuB...                 3141                    220
# Steamboat Springs...                  805                     89
# Syracuse-Auburn, ...                 9425                    783
# Tallahassee-Bainb...                 4570                    601
# Toledo-Port Clint...                 8507                    571
# Tucson-Nogales, A...                14349                   1345
# Tulsa-Muskogee-Ba...                15955                    940
# Tyler-Jacksonvill...                 3648                    163
# Victoria-Port Lav...                 1757                    109
# Virginia Beach-No...                19278                   2048
# Visalia-Portervil...                 5358                    223
# Washington-Baltim...               123544                  14766
# Wausau-Stevens Po...                 3834                    260
# Wichita-Arkansas ...                 9233                    538
# Williamsport-Lock...                 1807                     74
# Youngstown-Warren...                10346                    403
#
# [166 rows x 2 columns]
#                       Health Establishments  Educational Establishments
# Health Establishm...             1.000000               0.987437
# Educational Estab...             0.987437               1.000000
# /Users/user/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
health_pop_table = pandas.concat([flattened_all_health_est['Number of establishments'], latest_pop], axis=1)
health_pop_table['Residents per Health Est.'] = health_pop_table['Population Estimate (as of July 1) - 2015'] / health_pop_table['Number of establishments']
health_ratio_hist = health_pop_table['Residents per Health Est.'].plot(by='Residents per Health Est.', kind='hist', bins=20)
print(health_ratio_hist)
print(len(health_pop_table['Residents per Health Est.'].astype(float).dropna().as_matrix()))
# Out:
# Axes(0.125,0.125;0.775x0.775)
# 165

# %%
import matplotlib.pyplot as plt
import scipy
import scipy.stats
size = 130
x = scipy.arange(size)
y = health_pop_table['Residents per Health Est.'].astype(float).dropna().as_matrix()
h = plt.hist(y, bins=numpy.arange(40, 140, 5), color='b')

dist_names = ['gamma', 'beta', 'norm', 'pareto']

for dist_name in dist_names:
    dist = getattr(scipy.stats, dist_name)
    param = dist.fit(y)
    print(param)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=dist_name)
    plt.xlim(40,135)
plt.legend(loc='upper right')
plt.show()
# Out:
# (27.434247056346699, 11.838848064662521, 2.4761640465524448)
# (24.668178415810676, 574797.25549294217, 15.142631398638082, 1506080.2545884023)
# (79.770543955564577, 13.012694326312907)
# (1.8679704036190103, -0.10790103370296904, 46.153863740883899)
# /Users/user/anaconda/lib/python3.5/site-packages/scipy/optimize/minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# Figure out the average income.

# %%
business = pandas.read_csv('datasets/business_est_values.csv', sep=',', encoding='latin-1', skiprows=13, skipfooter=24) 
# converters={"Annual payroll ($1,000)":float, "Number of paid employees for pay period including March 12":float})
print(business.columns)
# Out:
# Index(['Geographic area name', 'Unnamed: 1', 'Unnamed: 2', '2012 NAICS code',
#        'Meaning of 2012 NAICS code', 'Meaning of Gender code', 'Unnamed: 6',
#        'Unnamed: 7', 'Meaning of Ethnicity code', 'Unnamed: 9',
#        'Meaning of Race code', 'Year',
#        'Number of firms with or without paid employees',
#        'Sales, receipts, or value of shipments of firms with or without paid employees ($1,000)',
#        'Number of firms with paid employees',
#        'Sales, receipts, or value of shipments of firms with paid employees ($1,000)',
#        'Number of paid employees for pay period including March 12',
#        'Payroll Per Employee', 'Annual payroll ($1,000)',
#        'Sales, receipts, or value of shipments of firms without paid employees ($1,000)',
#        'Relative standard error of number of firms with or without paid employees (%)',
#        'Relative standard error of sales, receipts, or value of shipments of firms with or without paid employees (%)',
#        'Relative standard error of number of firms with paid employees (%)',
#        'Relative standard error of sales, receipts, or value of shipments of firms with paid employees (%)',
#        'Relative standard error of number of paid employees for pay period including March 12 (%)',
#        'Relative standard error of annual payroll (%)'],
#       dtype='object')
# /Users/user/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
business_totals = business[business['Meaning of 2012 NAICS code'] == 'Total for all sectors']
business_grouped = business_totals[['Geographic area name', 'Payroll Per Employee']].groupby('Geographic area name').sum()
print(business_grouped.sort('Payroll Per Employee'))
# Out:
#                      Payroll Per Employee
# Geographic area name
# Brownsville-Harli...                   26
# McAllen-Edinburg,...                   26
# Clovis-Portales, ...                   27
# Hot Springs-Malve...                   28
# Martin-Union City...                   28
# Manhattan-Junctio...                   28
# Myrtle Beach-Conw...                   29
# El Paso-Las Cruce...                   29
# Lubbock-Levelland...                    3
# Fayetteville-Lumb...                   30
# New Bern-Morehead...                   31
# DeRidder-Fort Pol...                   31
# Cleveland-Indiano...                   31
# Jonesboro-Paragou...                   32
# Mount Pleasant-Al...                   32
# Johnstown-Somerse...                   32
# Rapid City-Spearf...                   32
# Pullman-Moscow, W...                   32
# Gainesville-Lake ...                   33
# Knoxville-Morrist...                   33
# Ithaca-Cortland, ...                   33
# Columbus-Auburn-O...                   33
# Macon-Warner Robi...                   33
# Dothan-Enterprise...                   33
# Idaho Falls-Rexbu...                   33
# Bloomington-Bedfo...                   33
# Visalia-Portervil...                   33
# Cape Girardeau-Si...                   33
# Richmond-Connersv...                   33
# Bowling Green-Gla...                   33
# ...                                   ...
# Nashville-Davidso...                   44
# Des Moines-Ames-W...                   44
# Milwaukee-Racine-...                   45
# Cincinnati-Wilmin...                   45
# Jacksonville-St. ...                   45
# Portland-Vancouve...                   45
# Birmingham-Hoover...                   45
# Bloomington-Ponti...                   45
# St. Louis-St. Cha...                   46
# Midland-Odessa, T...                   46
# Boise City-Mounta...                   46
# Sacramento-Rosevi...                   46
# Detroit-Warren-An...                   47
# Raleigh-Durham-Ch...                   47
# Minneapolis-St. P...              52053.0                 5627.0
# Peoria-Canton, IL...               4591.0                  312.0
# Hartford-West Har...              21587.0                 2021.0
# Boston-Worcester-...             112850.0                13233.0
# Washington-Baltim...             123544.0                14766.0
# Houston-The Woodl...              74019.0                 6118.0
# New York-Newark, ...             359049.0                38887.0
# San Jose-San Fran...             121463.0                14328.0
# Pueblo-Cañon City...               2584.0                  113.0
#
#                      Payroll Per Employee
# Brownsville-Harli...                   26
# McAllen-Edinburg,...                   26
# Clovis-Portales, ...                   27
# Hot Springs-Malve...                   28
# Martin-Union City...                   28
# Manhattan-Junctio...                   28
# Myrtle Beach-Conw...                   29
# El Paso-Las Cruce...                   29
# Lubbock-Levelland...                    3
# Fayetteville-Lumb...                   30
# New Bern-Morehead...                   31
# DeRidder-Fort Pol...                   31
# Cleveland-Indiano...                   31
# Jonesboro-Paragou...                   32
# Mount Pleasant-Al...                   32
# Johnstown-Somerse...                   32
# Rapid City-Spearf...                   32
# Pullman-Moscow, W...                   32
# Gainesville-Lake ...                   33
# Knoxville-Morrist...                   33
# Ithaca-Cortland, ...                   33
# Columbus-Auburn-O...                   33
# Macon-Warner Robi...                   33
# Dothan-Enterprise...                   33
# Idaho Falls-Rexbu...                   33
# Bloomington-Bedfo...                   33
# Visalia-Portervil...                   33
# Cape Girardeau-Si...                   33
# Richmond-Connersv...                   33
# Bowling Green-Gla...                   33
# ...                                   ...
# Des Moines-Ames-W...                   44
# Milwaukee-Racine-...                   45
# Cincinnati-Wilmin...                   45
# Jacksonville-St. ...                   45
# Portland-Vancouve...                   45
# Birmingham-Hoover...                   45
# Bloomington-Ponti...                   45
# St. Louis-St. Cha...                   46
# Midland-Odessa, T...                   46
# Boise City-Mounta...                   46
# Sacramento-Rosevi...                   46
# Detroit-Warren-An...                   47
# Raleigh-Durham-Ch...                   47
# Charlotte-Concord...                   47
# Los Angeles-Long ...                   47
# Dallas-Fort Worth...                   48
# Atlanta--Athens-C...                   48
# Seattle-Tacoma, W...                   50
# Philadelphia-Read...                   50
# Denver-Aurora, CO...                   50
# Chicago-Napervill...                   51
# Minneapolis-St. P...                   51
# Peoria-Canton, IL...                   52
# Hartford-West Har...                   52
# Boston-Worcester-...                   54
# Washington-Baltim...                   54
# Houston-The Woodl...                   55
# New York-Newark, ...                   61
# San Jose-San Fran...                   74
# Pueblo-Cañon City...                  NaN
#
# [167 rows x 3 columns]

# %%
full_table = pandas.concat([health_edu_est, business_grouped['Payroll Per Employee']], axis=1).sort('Payroll Per Employee')
full_table.astype(float).corr()
# Out:
# /Users/user/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                       Health Establishments  Educational Establishments  \
# Health Establishm...             1.000000               0.987437
# Educational Estab...             0.987437               1.000000
# Payroll Per Employee             0.590721               0.605346
#
#                       Payroll Per Employee
# Health Establishm...             0.590721
# Educational Estab...             0.605346
# Payroll Per Employee             1.000000

# %%
# flattened_all_edu_est['Number of establishments']
edu_table = pandas.concat([flattened_all_edu_est['Number of establishments'], latest_pop], axis=1)
full_table['Residents per Edu. Est.'] = edu_table['Population Estimate (as of July 1) - 2015'] / edu_table['Number of establishments']
full_table.astype(float).corr()
# Out:
#                       Health Establishments  Educational Establishments  \
# Health Establishm...             1.000000               0.987437
# Educational Estab...             0.987437               1.000000
# Payroll Per Employee             0.590721               0.605346
# Residents per Edu...            -0.296601              -0.306590
#
#                       Payroll Per Employee  Residents per Edu. Est.
# Health Establishm...             0.590721             -0.296601
# Educational Estab...             0.605346             -0.306590
# Payroll Per Employee             1.000000             -0.358772
# Residents per Edu...            -0.358772              1.000000

# %%
# flattened_all_edu_est['Number of establishments']
health_table = pandas.concat([flattened_all_health_est['Number of establishments'], latest_pop], axis=1)
full_table['Residents per Health Est.'] = health_table['Population Estimate (as of July 1) - 2015'] / health_table['Number of establishments']
full_table.astype(float).corr()
# Out:
#                       Health Establishments  Educational Establishments  \
# Health Establishm...             1.000000               0.987437
# Educational Estab...             0.987437               1.000000
# Payroll Per Employee             0.590721               0.605346
# Residents per Edu...            -0.296601              -0.306590
# Residents per Hea...            -0.157164              -0.144445
#
#                       Payroll Per Employee  Residents per Edu. Est.  \
# Health Establishm...             0.590721             -0.296601
# Educational Estab...             0.605346             -0.306590
# Payroll Per Employee             1.000000             -0.358772
# Residents per Edu...            -0.358772              1.000000
# Residents per Hea...            -0.074673              0.414564
#
#                       Residents per Health Est.
# Health Establishm...            -0.157164
# Educational Estab...            -0.144445
# Payroll Per Employee            -0.074673
# Residents per Edu...             0.414564
# Residents per Hea...             1.000000

# %%
business_floats = business_totals.astype(float).dropna()
# business_floats.astype(float).dropna()
business_floats_num['salary'] = business_floats['Annual payroll ($1,000)'] / business_floats['Number of paid employees for pay period including March 12']
print(business_floats_num)


business_floats = business[['Annual payroll ($1,000)', 'Number of paid employees for pay period including March 12']]
# business_floats_num = business_floats.apply(pandas.to_numeric, args=('coerce',))
business_floats = business_floats.apply(pandas.to_numeric, errors='raise').dropna()
# business_floats.astype(float).dropna()
business_floats_num['salary'] = business_floats['Annual payroll ($1,000)'] / business_floats['Number of paid employees for pay period including March 12']
print(business_floats_num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2203e62b66ea> in <module>()
# ----> 1 business_floats = business_totals.astype(float).dropna()
#       2 # business_floats.astype(float).dropna()
#       3 business_floats_num['salary'] = business_floats['Annual payroll ($1,000)'] / business_floats['Number of paid employees for pay period including March 12']
#       4 print(business_floats_num)
#       5
#
# /Users/user/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in astype(self, dtype, copy, raise_on_error, **kwargs)
#    2948
#    2949         mgr = self._data.astype(dtype=dtype, copy=copy,
# -> 2950                                 raise_on_error=raise_on_error, **kwargs)
#    2951         return self._constructor(mgr).__finalize__(self)
#    2952
#
# /Users/user/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    2936
#    2937     def astype(self, dtype, **kwargs):
# -> 2938         return self.apply('astype', dtype=dtype, **kwargs)
#    2939
#    2940     def convert(self, **kwargs):
#
# /Users/user/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# /Users/user/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in astype(self, dtype, copy, raise_on_error, values, **kwargs)
#     432                **kwargs):
#     433         return self._astype(dtype, copy=copy, raise_on_error=raise_on_error,
# --> 434                             values=values, **kwargs)
#     435
#     436     def _astype(self, dtype, copy=False, raise_on_error=True, values=None,
#
# /Users/user/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, raise_on_error, values, klass, mgr, **kwargs)
#     475
#     476                 # _astype_nansafe works fine with 1-d only
# --> 477                 values = com._astype_nansafe(values.ravel(), dtype, copy=True)
#     478                 values = values.reshape(self.shape)
#     479
#
# /Users/user/anaconda/lib/python3.5/site-packages/pandas/core/common.py in _astype_nansafe(arr, dtype, copy)
#    1918
#    1919     if copy:
# -> 1920         return arr.astype(dtype)
#    1921     return arr.view(dtype)
#    1922
#
# ValueError: could not convert string to float: '1,844,857'
