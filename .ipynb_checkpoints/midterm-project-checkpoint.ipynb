# %% [markdown]
# Midterm Project <br>
# Do Less Populated Regions Provide a Better Measure of Well-Being?
#
# The first step is to wrangle our data so that we are able to properly utilize the thinkstats2 and pandas libraries. We'll start with the data on educational establishments and build up better column names.

# %%
# %matplotlib inline

import numpy
import pandas
# import thinkstats2

frame = pandas.read_csv('datasets/educational_est_values.csv', sep=',', encoding='latin-1', skiprows=1)
print("List of columns\n")
print(frame.columns)
print("\nType of Educational Services and Totals\n")
print(frame['Meaning of 2012 NAICS code'].value_counts())
# Out:
# List of columns
#
# Index(['Geographic identifier code', 'Id2', 'Geographic area name',
#        '2012 NAICS code', 'Meaning of 2012 NAICS code',
#        'Type of operation or tax status code',
#        'Meaning of Type of operation or tax status code', 'Year',
#        'Number of establishments', 'Receipts/Revenue ($1,000)',
#        'Operating expenses ($1,000)', 'Annual payroll ($1,000)',
#        'First-quarter payroll ($1,000)',
#        'Number of paid employees for pay period including March 12',
#        'Percent of receipts/revenue from administrative records (%)',
#        'Percent of receipts/revenue estimated (%)'],
#       dtype='object')
#
# Type of Educational Services and Totals
#
# Educational support services                               1269
# Educational services                                        990
# Sports and recreation instruction                           922
# Fine arts schools                                           916
# ...

# %%
print(frame['Geographic area name'].value_counts())
# Out:
# New York-Newark, NY-NJ-CT-PA CSA                        92
# Los Angeles-Long Beach, CA CSA                          91
# Chicago-Naperville, IL-IN-WI CSA                        91
# San Jose-San Francisco-Oakland, CA CSA                  90
# Philadelphia-Reading-Camden, PA-NJ-DE-MD CSA            89
# Denver-Aurora, CO CSA                                   89
# Detroit-Warren-Ann Arbor, MI CSA                        89
# Boston-Worcester-Providence, MA-RI-NH-CT CSA            88
# Atlanta--Athens-Clarke County--Sandy Springs, GA CSA    88
# Houston-The Woodlands, TX CSA                           88
# Washington-Baltimore-Arlington, DC-MD-VA-WV-PA CSA      88
# Orlando-Deltona-Daytona Beach, FL CSA                   88
# Nashville-Davidson--Murfreesboro, TN CSA                88
# Miami-Fort Lauderdale-Port St. Lucie, FL CSA            87
# Albuquerque-Santa Fe-Las Vegas, NM CSA                  86
# Cincinnati-Wilmington-Maysville, OH-KY-IN CSA           86
# ...

# %%
#total_num_est = frame[['Geographic area name', 'Number of establishments']].groupby('Geographic area name').sum()
#print(total_num_est.sort())

grouped_by_geo = frame.groupby('Geographic area name')
sort_by_num_est = grouped_by_geo[['Number of establishments']].transform(sum).sort('Number of establishments')
sort1 = frame.ix[grouped_by_geo[['Number of establishments']].transform(sum).sort('Number of establishments').index]
print(sort1)
# Out:
#      Geographic identifier code  Id2              Geographic area name  \
# 7368               330M200US393  393        Moses Lake-Othello, WA CSA
# 7353               330M200US393  393        Moses Lake-Othello, WA CSA
# 7354               330M200US393  393        Moses Lake-Othello, WA CSA
# 7355               330M200US393  393        Moses Lake-Othello, WA CSA
# 7356               330M200US393  393        Moses Lake-Othello, WA CSA
# 7357               330M200US393  393        Moses Lake-Othello, WA CSA
# 7358               330M200US393  393        Moses Lake-Othello, WA CSA
# 7359               330M200US393  393        Moses Lake-Othello, WA CSA
# 7360               330M200US393  393        Moses Lake-Othello, WA CSA
# 7361               330M200US393  393        Moses Lake-Othello, WA CSA
# 7362               330M200US393  393        Moses Lake-Othello, WA CSA
# 7363               330M200US393  393        Moses Lake-Othello, WA CSA
# ...

# %%
print(total_num_est.max())
print(total_num_est.min())
# Out:
# Number of establishments    77774
# dtype: int64
# Number of establishments    42
# dtype: int64

# %% [markdown]
# Make histogram of region to establishment count.

# %%
import thinkstats2
no_outliers = frame[frame['Number of establishments'] < 500]
hist = thinkstats2.Hist(no_outliers['Number of establishments'])

# %% [markdown]
# Display the histogram.

# %%
import thinkplot
thinkplot.Hist(hist, label='establishments')
thinkplot.Show()

# %% [markdown]
# Figure out the average income.

# %%
business = pandas.read_csv('datasets/business_est_values.csv', sep=',', encoding='latin-1', skiprows=13, skipfooter=25)
print(business.columns)
# Out:
# Index(['Geographic area name', 'Unnamed: 1', 'Unnamed: 2', '2012 NAICS code',
#        'Meaning of 2012 NAICS code', 'Meaning of Gender code', 'Unnamed: 6',
#        'Unnamed: 7', 'Meaning of Ethnicity code', 'Unnamed: 9',
#        'Meaning of Race code', 'Year',
#        'Number of firms with or without paid employees',
#        'Sales, receipts, or value of shipments of firms with or without paid employees ($1,000)',
#        'Number of firms with paid employees',
#        'Sales, receipts, or value of shipments of firms with paid employees ($1,000)',
#        'Number of paid employees for pay period including March 12',
#        'Annual payroll ($1,000)',
#        'Sales, receipts, or value of shipments of firms without paid employees ($1,000)',
#        'Relative standard error of number of firms with or without paid employees (%)',
#        'Relative standard error of sales, receipts, or value of shipments of firms with or without paid employees (%)',
# ...

# %%
# Include only floats
# DenFrame_floats = DenFrame[(DenFrame.Hper.map(type) == float) & 
#                           (DenFrame.Vper.map(type) == float)]

# business_floats = business[(business['Annual payroll ($1,000)'].map(type) == num) & business['Number of paid employees for pay period including March 12'].map(type) == num]
# business_floats = business[business['Annual payroll ($1,000)'].apply(float)]
business_floats = business.dropna()

print(business)
print(business_floats['Annual payroll ($1,000)'] / business_floats['Number of paid employees for pay period including March 12'])
# Out:
#                         Geographic area name  Unnamed: 1  Unnamed: 2  \
# 0                                        NaN         NaN         NaN
# 1                 Albany-Schenectady, NY CSA         NaN         NaN
# 2                 Albany-Schenectady, NY CSA         NaN         NaN
# 3                 Albany-Schenectady, NY CSA         NaN         NaN
# 4                 Albany-Schenectady, NY CSA         NaN         NaN
# 5                 Albany-Schenectady, NY CSA         NaN         NaN
# 6                 Albany-Schenectady, NY CSA         NaN         NaN
# 7                 Albany-Schenectady, NY CSA         NaN         NaN
# 8                 Albany-Schenectady, NY CSA         NaN         NaN
# 9                 Albany-Schenectady, NY CSA         NaN         NaN
# 10                Albany-Schenectady, NY CSA         NaN         NaN
# 11                Albany-Schenectady, NY CSA         NaN         NaN
# 12                Albany-Schenectady, NY CSA         NaN         NaN
# ...
